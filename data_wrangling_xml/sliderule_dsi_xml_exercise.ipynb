# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %% [markdown]
# ### 1-10 countries with the lowest infant mortality rates

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
infants_rates = {}
for country in document.findall('country'):
    country_name = country.find('name').text
    country_infant_mortality = country.find('infant_mortality')
    if country_infant_mortality is not None :
        infants_rates[country_name] = float(country_infant_mortality.text)
infants_rates
# Out:
# {'Afghanistan': 117.23,
#  'Albania': 13.19,
#  'Algeria': 21.76,
#  'American Samoa': 8.92,
#  'Andorra': 3.69,
#  'Angola': 79.99,
#  'Anguilla': 3.4,
#  'Antigua and Barbuda': 13.29,
#  'Argentina': 9.96,
#  'Armenia': 13.97,
#  'Aruba': 11.74,
#  'Australia': 4.43,
#  'Austria': 4.16,
#  'Azerbaijan': 26.67,
#  'Bahamas': 12.5,
#  'Bahrain': 9.68,
#  'Bangladesh': 45.67,
#  'Barbados': 10.93,
#  'Belarus': 3.64,
#  'Belgium': 4.18,
#  'Belize': 20.31,
#  'Benin': 57.09,
#  'Bermuda': 2.48,
#  'Bhutan': 37.89,
#  'Bolivia': 38.61,
#  'Bosnia and Herzegovina': 5.84,
#  'Botswana': 9.38,
#  'Brazil': 19.21,
#  'British Virgin Islands': 13.45,
#  'Brunei': 10.48,
#  'Bulgaria': 15.08,
#  'Burkina Faso': 76.8,
#  'Burundi': 63.44,
#  'Cambodia': 51.36,
#  'Cameroon': 55.1,
#  'Canada': 4.71,
#  'Cape Verde': 24.28,
#  'Cayman Islands': 6.21,
#  'Central African Republic': 92.86,
#  'Chad': 90.3,
#  'Chile': 7.02,
#  'China': 14.79,
#  'Colombia': 15.02,
#  'Comoros': 65.31,
#  'Congo': 59.34,
#  'Cook Islands': 14.33,
#  'Costa Rica': 8.7,
#  'Cote dIvoire': 60.16,
#  'Croatia': 5.87,
#  'Cuba': 4.7,
#  'Cyprus': 8.54,
#  'Czech Republic': 2.63,
#  'Denmark': 4.1,
#  'Djibouti': 50.2,
#  'Dominica': 11.61,
#  'Dominican Republic': 19.63,
#  'Ecuador': 17.93,
#  'Egypt': 22.41,
#  'El Salvador': 18.44,
#  'Equatorial Guinea': 71.12,
#  'Eritrea': 38.44,
#  'Estonia': 6.7,
#  'Ethiopia': 55.77,
#  'Faroe Islands': 5.71,
#  'Fiji': 10.2,
#  'Finland': 3.36,
#  'France': 3.31,
#  'French Guiana': 14.6,
#  'French Polynesia': 4.78,
#  'Gabon': 47.03,
#  'Gambia': 65.74,
#  'Gaza Strip': 30.6,
#  'Georgia': 16.68,
#  'Germany': 3.46,
#  'Ghana': 38.52,
#  'Gibraltar': 6.29,
#  'Greece': 4.78,
#  'Greenland': 9.42,
#  'Grenada': 10.5,
#  'Guadeloupe': 8.3,
#  'Guam': 5.51,
#  'Guatemala': 23.51,
#  'Guernsey': 3.47,
#  'Guinea': 55.24,
#  'Guinea-Bissau': 90.92,
#  'Guyana': 33.56,
#  'Haiti': 49.43,
#  'Honduras': 18.72,
#  'Hong Kong': 2.73,
#  'Hungary': 5.09,
#  'Iceland': 3.15,
#  'India': 43.19,
#  'Indonesia': 25.16,
#  'Iran': 39.0,
#  'Iraq': 37.53,
#  'Ireland': 3.74,
#  'Isle of Man': 4.17,
#  'Israel': 3.98,
#  'Italy': 3.31,
#  'Jamaica': 13.69,
#  'Japan': 2.13,
#  'Jersey': 3.86,
#  'Jordan': 15.73,
#  'Kazakhstan': 21.61,
#  'Kenya': 40.71,
#  'Kiribati': 35.37,
#  'Kuwait': 7.51,
#  'Kyrgyzstan': 28.71,
#  'Laos': 54.53,
#  'Latvia': 7.91,
#  'Lebanon': 7.98,
#  'Lesotho': 50.48,
#  'Liberia': 69.19,
#  'Libya': 11.87,
#  'Liechtenstein': 4.33,
#  'Lithuania': 6.0,
#  'Luxembourg': 4.28,
#  'Macao': 3.13,
#  'Macedonia': 7.9,
#  'Madagascar': 44.88,
#  'Malawi': 48.01,
#  'Malaysia': 13.69,
#  'Maldives': 24.59,
#  'Mali': 104.34,
#  'Malta': 3.59,
#  'Marshall Islands': 21.39,
#  'Martinique': 7.1,
#  'Mauritania': 56.06,
#  'Mauritius': 10.59,
#  'Mayotte': 56.29,
#  'Mexico': 12.58,
#  'Micronesia': 21.93,
#  'Moldova': 12.93,
#  'Monaco': 1.81,
#  'Mongolia': 23.15,
#  'Montserrat': 13.66,
#  'Morocco': 24.52,
#  'Mozambique': 72.42,
#  'Myanmar': 44.91,
#  'Namibia': 45.64,
#  'Nauru': 8.21,
#  'Nepal': 40.43,
#  'Netherlands': 3.66,
#  'New Caledonia': 5.46,
#  'New Zealand': 4.59,
#  'Nicaragua': 20.36,
#  'Niger': 86.27,
#  'Nigeria': 74.09,
#  'North Korea': 24.5,
#  'Northern Mariana Islands': 5.5,
#  'Norway': 2.48,
#  'Oman': 14.0,
#  'Pakistan': 57.48,
#  'Palau': 11.46,
#  'Panama': 10.7,
#  'Papua New Guinea': 39.67,
#  'Paraguay': 20.75,
#  'Peru': 20.21,
#  'Philippines': 17.64,
#  'Poland': 6.19,
#  'Portugal': 4.48,
#  'Puerto Rico': 7.73,
#  'Qatar': 6.42,
#  'Reunion': 7.5,
#  'Romania': 10.16,
#  'Russia': 7.08,
#  'Rwanda': 59.59,
#  'Saint Helena': 17.63,
#  'Saint Kitts and Nevis': 8.98,
#  'Saint Lucia': 11.75,
#  'Saint Pierre and Miquelon': 6.95,
#  'Saint Vincent and the Grenadines': 13.07,
#  'Samoa': 20.5,
#  'San Marino': 4.52,
#  'Sao Tome and Principe': 49.16,
#  'Saudi Arabia': 14.58,
#  'Senegal': 52.72,
#  'Serbia': 6.16,
#  'Seychelles': 10.77,
#  'Sierra Leone': 73.29,
#  'Singapore': 2.53,
#  'Sint Maarten': 9.05,
#  'Slovakia': 5.35,
#  'Slovenia': 4.04,
#  'Solomon Islands': 16.17,
#  'Somalia': 100.14,
#  'South Africa': 41.61,
#  'South Korea': 3.93,
#  'South Sudan': 68.16,
#  'Spain': 3.33,
#  'Sri Lanka': 9.02,
#  'Sudan': 52.86,
#  'Suriname': 27.07,
#  'Swaziland': 54.82,
#  'Sweden': 2.6,
#  'Switzerland': 3.73,
#  'Syria': 15.79,
#  'Taiwan': 4.49,
#  'Tajikistan': 35.03,
#  'Tanzania': 43.74,
#  'Thailand': 9.86,
#  'Timor-Leste': 38.79,
#  'Togo': 46.73,
#  'Tonga': 12.36,
#  'Trinidad and Tobago': 24.82,
#  'Tunisia': 23.19,
#  'Turkey': 21.43,
#  'Turkmenistan': 38.13,
#  'Turks and Caicos Islands': 10.97,
#  'Tuvalu': 31.69,
#  'Uganda': 60.82,
#  'Ukraine': 8.1,
#  'United Arab Emirates': 10.92,
#  'United Kingdom': 4.44,
#  'United States': 6.17,
#  'Uruguay': 8.97,
#  'Uzbekistan': 19.84,
#  'Vanuatu': 16.41,
#  'Venezuela': 19.33,
#  'Vietnam': 18.99,
#  'Virgin Islands': 6.79,
#  'Wallis and Futuna': 4.49,
#  'West Bank': 28.6,
#  'Western Sahara': 145.82,
#  'Yemen': 50.41,
#  'Zaire': 73.15,
#  'Zambia': 66.62,
#  'Zimbabwe': 26.55}

# %%
sorted_infants_rates = sorted(infants_rates.items(), key=lambda x: x[1])
sorted_infants_rates[0:10]
# Out:
# [('Monaco', 1.81),
#  ('Japan', 2.13),
#  ('Bermuda', 2.48),
#  ('Norway', 2.48),
#  ('Singapore', 2.53),
#  ('Sweden', 2.6),
#  ('Czech Republic', 2.63),
#  ('Hong Kong', 2.73),
#  ('Macao', 3.13),
#  ('Iceland', 3.15)]

# %% [markdown]
# ### 2- 10 cities with the largest population

# %% [markdown]
# I will assume that the population of any city = the latest census of this city

# %%
city_population = {}
for country in document.findall('country'):
    for city in country.iter('city'):
        city_name = city.find('name').text
        latest_population_year = 0
        for population in city.iter('population'):
            population_year = int(population.get('year'))
            if(population_year > latest_population_year):
                latest_population_year = population_year
                city_pop = float(population.text)
        city_population[city_name] = city_pop
city_population
# Out:
# {'Akure': 239124.0,
#  u'\xc1guas Lindas de Goi\xe1s': 159138.0,
#  'Yibin': 241019.0,
#  'Szczecin': 409211.0,
#  'Lianyungang': 354139.0,
#  'Machakos': 150041.0,
#  'Toledo': 287206.0,
#  'Zhaodong': 179976.0,
#  'Zinder': 322935.0,
#  'Fayetteville': 200574.0,
#  'Pomona': 149058.0,
#  'Usak': 187886.0,
#  'Sacaba': 169494.0,
#  'Liverpool': 552267.0,
#  'High Wycombe': 120256.0,
#  'Livingstone': 1269848.0,
#  'Novi Sad': 335701.0,
#  'Mitu': 131545.0,
#  'Choluteca': 120791.0,
#  'Panshan': 362773.0,
#  'Mito': 1020241.0,
#  u'San Pedro Garza Garc\xeda': 122627.0,
#  'Caen': 108793.0,
#  u'Maring\xe1': 350653.0,
#  'La Chorrera': 161470.0,
#  'Terrassa': 214406.0,
#  'Oshogbo': 250951.0,
#  'Exeter': 113507.0,
#  'Jeju': 399416.0,
#  'Talara': 87622.0,
#  'Ar Ramadi': 192556.0,
#  'Saitama': 1223954.0,
#  'San Fernando del Valle de Catamarca': 140556.0,
#  'Sheikhupura': 280263.0,
#  'Tonsberg': 8984.0,
#  'Tougourt': 143270.0,
#  'Windsor': 210891.0,
#  'Aijal': 1727692.0,
#  'Tanjungpinang': 174758.0,
#  'Strasbourg': 272222.0,
#  'Indaiatuba': 199592.0,
#  'Novomoskovsk': 131386.0,
#  u'Dzer\u017einsk': 240742.0,
#  'Kirikkale': 192473.0,
#  'Cotia': 201150.0,
#  'Fatick': 101984.0,
#  'Ramla': 65800.0,
#  'Wuhu': 425740.0,
#  'Ansan': 722598.0,
#  'Siping': 317223.0,
#  'Varginha': 119061.0,
#  'Gangtok': 402700.0,
#  'Cherkasy': 286163.0,
#  'Tahoua': 149498.0,
#  'Itapecerica da Serra': 151349.0,
#  'Newcastle upon Tyne': 268064.0,
#  'Hamilton': 132060.0,
#  'Tabriz': 1494998.0,
#  'Poltava': 297589.0,
#  'Chipata': 186372.0,
#  "'s-Hertogenbosch": 143822.0,
#  u'Camag\xfcey': 307841.0,
#  'Jinzhou': 569518.0,
#  'Grudziadz': 98726.0,
#  'Viborg': 104885.0,
#  'Eindhoven': 221279.0,
#  'Caruaru': 279589.0,
#  u'M\xe1laga': 561435.0,
#  'Buffalo City': 755200.0,
#  'Tuzla': 120441.0,
#  'Zhoushan': 156317.0,
#  u'J\xf6nk\xf6ping': 129478.0,
#  'Stuttgart': 585890.0,
#  'Kitakyushu': 974691.0,
#  'Dammam': 744321.0,
#  'Utrecht': 330081.0,
#  u'Ploie\u015fti': 209945.0,
#  'Ulan-Ude': 416079.0,
#  'Maradi': 267249.0,
#  'Ferrara': 132545.0,
#  'Ichikawa': 458679.0,
#  'Narvik': 18754.0,
#  'Pembroke Pines': 154019.0,
#  'Wolverhampton': 210319.0,
#  'Ashgabat': 604700.0,
#  'Quezon City': 2679450.0,
#  'Obninsk': 104739.0,
#  'Yuscaran': 135136.0,
#  'Bimbo': 124176.0,
#  'Yuanjiang': 107004.0,
#  'Hamar': 15685.0,
#  'Sousse': 223844.0,
#  'Las Vegas': 603488.0,
#  'As Sulaymaniyah': 364096.0,
#  u'\u017deleznodoro\u017enyj': 131257.0,
#  'Nukualofa': 23658.0,
#  'Doncaster': 109805.0,
#  'Nigde': 118186.0,
#  'Schwerin': 91293.0,
#  'Lyon': 491268.0,
#  'Waterbury': 110366.0,
#  'Ciudad del Este': 222274.0,
#  'Ganja': 322600.0,
#  'Parla': 122045.0,
#  'Mandaluyong': 305576.0,
#  u'Ivano-Frankivs\xb4k': 224660.0,
#  'Aguascalientes': 722250.0,
#  'Bareilly': 590661.0,
#  'Khartoum North': 700887.0,
#  'Messina': 243262.0,
#  'Getafe': 168642.0,
#  'Urganch': 137300.0,
#  'Siguatepeque': 60155.0,
#  u'\xd6rebro': 138952.0,
#  u'Sidi Bel Abb\xebs': 210146.0,
#  'Laiyang': 137080.0,
#  'Goma': 109094.0,
#  'Zapopan': 1142483.0,
#  'Leshan': 341128.0,
#  'Zhanjiang': 400997.0,
#  'Singida': 150379.0,
#  'Akron': 199092.0,
#  'Jiamusi': 493409.0,
#  'Leiria': 50608.0,
#  'Magnitogorsk': 411880.0,
#  u'Al Ubayyi\u1e11': 229425.0,
#  'Tonala': 408759.0,
#  'Jiaozuo': 409100.0,
#  'Bilbao': 351356.0,
#  u'Gen\xe8ve': 191557.0,
#  'Bogra': 350397.0,
#  'Imphal': 1727692.0,
#  'Bo': 149957.0,
#  "Ba'qubah": 114516.0,
#  'Cheltenham': 116447.0,
#  'Barreiras': 123741.0,
#  'Jeonju': 643079.0,
#  'Iringa': 151345.0,
#  'Yakeshi': 377869.0,
#  'Oruro': 264683.0,
#  'Sokhumi': 62914.0,
#  'Lund': 112950.0,
#  'Cottbus': 99984.0,
#  'Ciudad Delgado': 129965.0,
#  'Villahermosa': 353577.0,
#  'Awka': 104682.0,
#  'Aba': 500183.0,
#  'Karaman': 141630.0,
#  'Sari': 296417.0,
#  'Cobija': 106422.0,
#  'Mardin': 86948.0,
#  'Bila Tserkva': 210551.0,
#  'Himeji': 533832.0,
#  'Surakarta': 499337.0,
#  'Toulon': 163974.0,
#  'Tampere': 220678.0,
#  u'Cap-Ha\xeftien': 155505.0,
#  'Warri': 363382.0,
#  'Karamay': 197602.0,
#  'Comayagua': 87474.0,
#  'Puerto Lempira': 60155.0,
#  'Willemstad': 125000.0,
#  'Buraydah': 918889.0,
#  'Phoenix': 1513367.0,
#  'Mansa': 186372.0,
#  'Qianjiang': 205504.0,
#  'Tlaquepaque': 575942.0,
#  'Arequipa': 749291.0,
#  'Irving': 216287.0,
#  'Faridabad': 1414050.0,
#  'Hartford': 124775.0,
#  'Sedhiou': 162887.0,
#  'Yinchuan': 356652.0,
#  u'Novo\u010derkassk': 168746.0,
#  'Dhaka': 7423137.0,
#  'Sioux Falls': 153897.0,
#  u'Te\xf3filo Otoni': 110076.0,
#  u'Jyv\xe4skyl\xe4': 134862.0,
#  'Cuernavaca': 338650.0,
#  u'Bayr\u016bt': 1100000.0,
#  'Chesapeake': 222209.0,
#  'Saskatoon': 222189.0,
#  u'K\xf6ln': 1005775.0,
#  'Villavicencio': 473766.0,
#  'Giugliano in Campania': 108793.0,
#  'Ekurhuleni - Germiston': 3178471.0,
#  'Kawasaki': 1388481.0,
#  'Saratov': 839755.0,
#  'Linfen': 187309.0,
#  'Road Town': 8555272.0,
#  'Luleburgaz': 105279.0,
#  u'\u0141\xf3d\u017a': 722022.0,
#  'Cerro de Pasco': 370962.0,
#  'Glarus': 191557.0,
#  'Moroni': 41557.0,
#  'Jinan': 4335989.0,
#  'Santo Domingo': 2749703.0,
#  'Salinas': 150498.0,
#  'Ganzhou': 220129.0,
#  'Santa Cruz de la Sierra': 1453549.0,
#  'Obuasi': 143644.0,
#  'Duque de Caxias': 852138.0,
#  'Lauro de Freitas': 163449.0,
#  'Adelaide': 1262940.0,
#  u'Uberl\xe2ndia': 587266.0,
#  'Dutse': 119711.0,
#  'Bariadi': 102900.0,
#  'Monterrey': 1135512.0,
#  'San Miguel': 218410.0,
#  u'\u010cesk\xe9 Bud\u011bjovice': 95589.0,
#  'Norwalk': 105549.0,
#  'Arlington': 207628.0,
#  'Badajoz': 151214.0,
#  'Montgomery': 205597.0,
#  'Newark': 277138.0,
#  'Adamstown': 391.0,
#  'Ontario': 163924.0,
#  'Haicheng': 205560.0,
#  'Nam Dinh': 193768.0,
#  'Smolensk': 330970.0,
#  'Wigan': 103608.0,
#  'Kristiansand': 84476.0,
#  'Rajshahi': 440604.0,
#  'Tianshui': 244974.0,
#  'Malabo': 92900.0,
#  'Bocas del Toro': 122924.0,
#  'Eskilstuna': 98765.0,
#  'Guarapuava': 152993.0,
#  'Coimbra': 118016.0,
#  'Kotka': 54714.0,
#  'Zadar': 70674.0,
#  'Anshan': 1390000.0,
#  'Jalingo': 329639.0,
#  'Tanga': 273332.0,
#  'Suqian': 105021.0,
#  'Vallejo': 115940.0,
#  u'Tarn\xf3w': 113188.0,
#  u'C\xe1diz': 124014.0,
#  'Nacaome': 84641.0,
#  'Nagpur': 2405665.0,
#  u'S\xe3o Caetano do Sul': 149263.0,
#  'Tambov': 281834.0,
#  u'Guant\xe1namo': 222243.0,
#  'Dimashq': 1552161.0,
#  'Rostock': 200265.0,
#  'Marseille': 850636.0,
#  'Koksetau': 140846.0,
#  'Appenzell': 111374.0,
#  'Huelva': 147808.0,
#  'Avarua': 418292.0,
#  u'Chorz\xf3w': 111314.0,
#  'Soyapango': 268228.0,
#  'Huizhou': 2344634.0,
#  u'Besan\xe7on': 115879.0,
#  u'Culiac\xe1n': 675773.0,
#  'Fort Worth': 792727.0,
#  'Zhangjiakou': 529136.0,
#  'Asosa': 147592.0,
#  'Nijmegen': 168810.0,
#  'Eisenstadt': 13485.0,
#  'Santa Ana de Coro': 158763.0,
#  'Rubcovsk': 147002.0,
#  'Durgapur': 425836.0,
#  'Tangerang': 1798601.0,
#  'Dortmund': 571143.0,
#  'Vila Real': 91108.0,
#  'Guilin': 364130.0,
#  'Majunga': 106780.0,
#  'Kupang': 336239.0,
#  'Rawalpindi': 1409768.0,
#  'Chiba': 937146.0,
#  'Tepic': 332863.0,
#  'Salekhard': 42544.0,
#  'Acarigua': 129237.0,
#  'Tanout': 154238.0,
#  u'Novokujby\u0161evsk': 108438.0,
#  'Chincha Alta': 153598.0,
#  'Baoding': 483155.0,
#  'Serang': 577785.0,
#  'Seongnam': 951424.0,
#  u'Bayam\xf3n': 185996.0,
#  'Ruian': 156468.0,
#  'Barbacena': 115568.0,
#  'Taguig': 613343.0,
#  'Presidente Prudente': 203375.0,
#  'Praia': 131719.0,
#  'Gagnoa': 167900.0,
#  u'Ibagu\xe9': 548209.0,
#  'Beipiao': 194301.0,
#  'Rotherham': 109691.0,
#  'Krefeld': 222247.0,
#  "Kamensk-Ural'skij": 174689.0,
#  'Divo': 105859.0,
#  'Akjoujt': 49152.0,
#  'Sirjan': 185623.0,
#  'Salzburg': 146676.0,
#  'Guiglo': 148171.0,
#  'Luzhou': 262892.0,
#  'LAquila': 117166.0,
#  u'Cuautitl\xe1n Izcalli': 484573.0,
#  u'\xc7orlu': 235354.0,
#  'Yasuj': 108505.0,
#  'Den Haag': 509623.0,
#  'Toliara': 80826.0,
#  'Vinh': 215577.0,
#  'Ha Long': 201990.0,
#  'Cambridge': 145818.0,
#  'Woking': 105367.0,
#  'Jijiga': 147482.0,
#  'Miskolc': 167754.0,
#  u'Guaruj\xe1': 290696.0,
#  'Nashik': 1486053.0,
#  'Qazvin': 381598.0,
#  'Ciudad Guayana': 692215.0,
#  'Yamaguchi': 465645.0,
#  'El Monte': 113475.0,
#  'Los Teques': 183142.0,
#  'Dayr az Zawr': 239196.0,
#  u'Jo\xe3o Pessoa': 720785.0,
#  u'Para\xf1aque': 552660.0,
#  'Halle': 229153.0,
#  'Mashhad': 2749374.0,
#  'Umuahia': 147167.0,
#  'Whitehorse': 23276.0,
#  'Brazzaville': 1408150.0,
#  'Talca': 189505.0,
#  'Changhua': 236636.0,
#  'West Island': 204949.0,
#  'Ijebu-Ode': 124313.0,
#  'An Najaf': 309010.0,
#  'Ardebil': 482632.0,
#  'Jiaoxian': 153364.0,
#  'Renqiu': 114256.0,
#  'Okara': 201815.0,
#  u'Bucure\u015fti': 1883425.0,
#  'Haeju': 273300.0,
#  'Sokoto': 329639.0,
#  'Quetta': 565137.0,
#  'Seattle': 652405.0,
#  'Faisalabad': 2008861.0,
#  'Braganca': 114003.0,
#  'Braunschweig': 242537.0,
#  'Cheongju': 667726.0,
#  'Mesa': 439611.0,
#  u'P\xe1dova': 206192.0,
#  'Koror': 11665.0,
#  'Coquimbo': 148438.0,
#  'Markham': 301709.0,
#  'Bani Suwayf': 193535.0,
#  u'B\xe9char': 165241.0,
#  'Pasadena': 149300.0,
#  'Gent': 248813.0,
#  'Burnaby': 223218.0,
#  'Malindi': 118265.0,
#  'San Felipe': 328636.0,
#  'Ife': 186856.0,
#  'Sendai': 1020241.0,
#  'Hachioji': 553914.0,
#  'Luohe': 126438.0,
#  'Anderlecht': 113462.0,
#  'Charleston': 51347.0,
#  'Surrey': 468251.0,
#  u'Vi\xf1a del Mar': 286931.0,
#  'Canberra': 418292.0,
#  'Longjing': 139417.0,
#  'Ondo': 146051.0,
#  'Akita': 1020241.0,
#  'Belgorod': 373528.0,
#  'Amritsar': 1132383.0,
#  'Volgograd': 1018790.0,
#  u'Krak\xf3w': 759131.0,
#  'Spring Valley': 178395.0,
#  'Trinidad': 106422.0,
#  'Gera': 96067.0,
#  'Depok': 1738570.0,
#  'Chicago': 2718782.0,
#  'Warangal': 447653.0,
#  'Angra dos Reis': 163290.0,
#  'Barreiro': 79042.0,
#  u'Buz\u0103u': 115494.0,
#  'Araraquara': 202730.0,
#  u'Tuxtla Guti\xe9rrez': 537102.0,
#  'Parma': 175895.0,
#  'Curitiba': 1751907.0,
#  'Mwene-Ditu': 137459.0,
#  'Charlottetown': 34562.0,
#  'Yeosu': 267921.0,
#  'Malambo': 119286.0,
#  'Bulawayo': 653337.0,
#  u'Crici\xfama': 189630.0,
#  'Suwon': 1064951.0,
#  u'Elbl\u0105g': 123977.0,
#  'Wuppertal': 342661.0,
#  'Gujrat': 251792.0,
#  'Grand Rapids': 188051.0,
#  'Oxnard': 197899.0,
#  'Moers': 104009.0,
#  'Ulaanbaatar': 760077.0,
#  'San-Pedro': 174287.0,
#  'Chongqing': 7457600.0,
#  'Bakersfield': 347568.0,
#  'Tarragona': 133223.0,
#  'Jersey City': 247643.0,
#  'Panaji': 1684222.0,
#  'Francisco Morato': 154158.0,
#  'Moradabad': 429214.0,
#  'Port Louis': 1094628.0,
#  'Shaoxing': 179818.0,
#  'Tarsus': 245671.0,
#  'Tema': 139784.0,
#  'San Bernardino': 209959.0,
#  'Santo Domingo de los Colorados': 305632.0,
#  'Tbilisi': 1073345.0,
#  'Mariehamn': 10851.0,
#  'Trenton': 84913.0,
#  u'St. P\xf6lten': 52100.0,
#  'Shishou': 104571.0,
#  'Osmaniye': 209255.0,
#  'Sofia': 1270284.0,
#  'Kiffa': 60005.0,
#  'Guacara': 141762.0,
#  'Laval': 401553.0,
#  'Lisboa': 559248.0,
#  'Antalya': 1073794.0,
#  'Corpus Christi': 305215.0,
#  'Itu': 144269.0,
#  u'Logro\xf1o': 152698.0,
#  'Santa Rita': 103717.0,
#  'Zanzibar': 223033.0,
#  u'Mykola\xefv': 497032.0,
#  'Quillacollo': 137029.0,
#  'Echeng': 190123.0,
#  'Kryvyi Rih': 660203.0,
#  'George Town': 646449.0,
#  'Ndola': 441624.0,
#  'Guliston': 509000.0,
#  u'Blagove\u0161\u010densk': 214390.0,
#  'Paradise': 223167.0,
#  u'Po\xe7os de Caldas': 148722.0,
#  'San Fernando': 205866.0,
#  'Bordeaux': 239399.0,
#  'Bhopal': 1798218.0,
#  'Kiel': 235782.0,
#  'Timon': 135133.0,
#  'Gombe': 163604.0,
#  'Santiago': 4659048.0,
#  'Novara': 101952.0,
#  'Kota Kinabalu': 354153.0,
#  'Rio Branco': 308545.0,
#  'Bie': 513000.0,
#  'Ikare': 103843.0,
#  u'N\xfcrnberg': 486314.0,
#  u'S\xe3o Lu\xeds': 958522.0,
#  "Farg'ona": 264900.0,
#  'Puerto Cabello': 177751.0,
#  'Ilesha': 139445.0,
#  'Yueyang': 302800.0,
#  'Nantes': 287845.0,
#  'Passo Fundo': 180120.0,
#  'Fuyang': 179572.0,
#  'Bondoukou': 542082.0,
#  'Molenbeek-Saint-Jean': 94653.0,
#  'Lages': 153937.0,
#  'Sfax': 299235.0,
#  u"\u0116ngel's": 202419.0,
#  'Chittagong': 2971102.0,
#  'Wakefield': 99251.0,
#  'Mukono': 161996.0,
#  'Bellinzona': 74581.0,
#  'Suva': 75225.0,
#  'Rahimyar Khan': 233537.0,
#  'Nuuk': 64425.0,
#  'Sterlitamak': 275798.0,
#  'Gloucester': 136362.0,
#  'Barrancabermeja': 191784.0,
#  'Al Ladhiqiyah': 424392.0,
#  'Orechovo-Zujevo': 120670.0,
#  'Sargodha': 458440.0,
#  'Concord': 42695.0,
#  'Pescara': 117166.0,
#  u'Pozna\u0144': 552393.0,
#  'Montes Claros': 344427.0,
#  'Durham': 228404.0,
#  'Cirilo Guainora': 88997.0,
#  'Yingkou': 421589.0,
#  'Chula Vista': 243916.0,
#  'Tokushima': 465645.0,
#  u'Li\xe8ge': 195931.0,
#  'Bello': 447185.0,
#  'Jackson': 173513.0,
#  'Caracas': 1975786.0,
#  'Hunjiang': 482043.0,
#  'Oporto': 266790.0,
#  u'Luts\xb4k': 213063.0,
#  u'Aragua\xedna': 142925.0,
#  'Sydney': 4605992.0,
#  'Yozgat': 78328.0,
#  'Pasig': 617301.0,
#  'Khanty Mansijsk': 80151.0,
#  'Chernihiv': 296723.0,
#  'Szombathely': 78884.0,
#  'Jodhpur': 1033756.0,
#  'Mejicanos': 157188.0,
#  'Chimbote': 334568.0,
#  'Ufa': 1077719.0,
#  'Birobidzhan': 75413.0,
#  'Rangpur': 294265.0,
#  u'W\xfcrzburg': 124297.0,
#  'Fortaleza': 2452185.0,
#  'Puntarenas': 119814.0,
#  u'V\xe1rzea Grande': 248704.0,
#  'Neftejugansk': 122855.0,
#  u'F\xfcrth': 115613.0,
#  'San Antonio': 1409019.0,
#  'Naha': 605120.0,
#  'Mufulira': 204104.0,
#  'Taiping': 183320.0,
#  'Jizzax': 163200.0,
#  'Stavanger': 129191.0,
#  'Az Zaqaziq': 302611.0,
#  u'Itabora\xed': 215412.0,
#  "Podol'sk": 187961.0,
#  'Fuzhou': 3572421.0,
#  'Binjai': 246154.0,
#  'Ruse': 146609.0,
#  'Cheboksary': 464940.0,
#  'Bauru': 338184.0,
#  'Ponta Delgada': 46102.0,
#  'Balkhash': 71203.0,
#  'Zaporizhzhia': 772627.0,
#  'Erbil': 850000.0,
#  'Sobral': 166310.0,
#  'Kirkuk': 750000.0,
#  'Kananga': 393030.0,
#  'Libreville': 538195.0,
#  'Maanshan': 305421.0,
#  'Aberdeen': 195021.0,
#  u'Hortol\xe2ndia': 192692.0,
#  'Tula': 493813.0,
#  'Jining': 163552.0,
#  'Wollongong': 288101.0,
#  'Chelyabinsk': 1156201.0,
#  'Aqtobe': 377520.0,
#  'Mongu': 1269848.0,
#  'Manisa': 309050.0,
#  'Fullerton': 135258.0,
#  'Vadodara': 1670806.0,
#  'Bandar Lampung': 881801.0,
#  'Aswan': 265004.0,
#  'Asyut': 386086.0,
#  'Muscat': 27216.0,
#  'Alor Setar': 114949.0,
#  'Banha': 158389.0,
#  'Armavir': 188832.0,
#  'Dolisie': 128032.0,
#  'Manaus': 1792881.0,
#  'Le Mans': 143240.0,
#  'Molde': 21448.0,
#  'Manzhouli': 120023.0,
#  'Chuxian': 125341.0,
#  u'Pu\u0161kino': 102874.0,
#  'Jiangyou': 175753.0,
#  'Salford': 103886.0,
#  'Algiers': 2364230.0,
#  'Zhumadian': 123232.0,
#  'Sabadell': 206949.0,
#  'Bien Hoa': 652646.0,
#  'Tokyo': 8591695.0,
#  'Mopti': 114296.0,
#  'Helsingborg': 132011.0,
#  'Long Xuyen': 245699.0,
#  'Peristeri': 139981.0,
#  'Ahmadabad': 5577940.0,
#  'Anaheim': 336511.0,
#  'Adama': 271562.0,
#  'Andijon': 403900.0,
#  'As Samawah': 208797.0,
#  'Juticalpa': 84641.0,
#  'Hermannsverk': 706.0,
#  'Amiens': 133327.0,
#  'Worcester': 181041.0,
#  'Yoshkar-Ola': 257015.0,
#  'Edirne': 148474.0,
#  'Djambala': 128032.0,
#  'Cleveland': 396697.0,
#  'Jilin': 1270000.0,
#  'Liling': 108504.0,
#  'Fukuoka': 1422831.0,
#  'Tianjin': 11090314.0,
#  'Santarem': 72576.0,
#  'Athens': 115453.0,
#  'Iskenderun': 184833.0,
#  'Angren': 175400.0,
#  'Satu Mare': 102411.0,
#  'Hail': 744321.0,
#  'Oradea': 196367.0,
#  'Al Mahallah al Kubra': 442884.0,
#  'Heidelberg': 146751.0,
#  'Karlsruhe': 289173.0,
#  'Georgetown': 118363.0,
#  'Cankiri': 111137.0,
#  'Huangshi': 457601.0,
#  'Kaolack': 190927.0,
#  'Mbeya': 385279.0,
#  'Prato': 185456.0,
#  'Sinop': 135350.0,
#  'Harrisburg': 49528.0,
#  'Torrance': 145438.0,
#  'Dosquebradas': 196926.0,
#  'Hamah': 467807.0,
#  u'Ia\u015fi': 290422.0,
#  'Kimberley': 588794.0,
#  'Budapest': 1729040.0,
#  'Bydgoszcz': 362286.0,
#  'Jakarta': 9607787.0,
#  'Xichang': 134419.0,
#  'Moyobamba': 216716.0,
#  'Santa Marta': 476385.0,
#  'Bristol': 535907.0,
#  'Aachen': 236420.0,
#  'Providence': 178042.0,
#  'Anyang': 603184.0,
#  'La Paz': 764617.0,
#  'Tijuana': 1300983.0,
#  'Kerch': 145845.0,
#  'Leicester': 443760.0,
#  'Mogi das Cruzes': 357313.0,
#  'Athina': 664046.0,
#  'Durango': 518709.0,
#  'Okhotsk': 4215.0,
#  u'R\u012bga': 696618.0,
#  u'G\xe4vle': 96170.0,
#  'Portland': 609456.0,
#  'Piura': 377496.0,
#  u'\u015eanl\u0131urfa': 526247.0,
#  u'Macap\xe1': 381214.0,
#  'Espoo': 261654.0,
#  'Kerman': 534441.0,
#  'Kidal': 127368.0,
#  'Murom': 116075.0,
#  'Mysore': 606755.0,
#  u"Santa B\xe1rbara d'Oeste": 178596.0,
#  'Thane': 1841488.0,
#  u'Ribeir\xe3o das Neves': 294153.0,
#  'Biel': 53031.0,
#  'Hebi': 212976.0,
#  'Neftekamsk': 121733.0,
#  'Al Rayyan': 272860.0,
#  u'Rzesz\xf3w': 180776.0,
#  'Al Iskandariyah': 4123869.0,
#  u'S\xe3o Leopoldo': 213238.0,
#  'Masaya': 166588.0,
#  u'Bragan\xe7a Paulista': 142255.0,
#  'Shenzhen': 10358381.0,
#  'Zaragoza': 678115.0,
#  u'\u0130neg\xf6l': 177617.0,
#  'Qinzhou': 114586.0,
#  'Tiraspol': 148917.0,
#  'Dunedin': 123516.0,
#  'Yancheng': 296831.0,
#  "Xi'an": 6501190.0,
#  'Gao': 1809106.0,
#  'Celaya': 340387.0,
#  'Baghdad': 5750000.0,
#  'Flint': 102400.0,
#  'Chimki': 207425.0,
#  'Chake Chake': 223033.0,
#  'Neiva': 340046.0,
#  'Tampa': 335715.0,
#  'Saurimo': 5000000.0,
#  u'General San Mart\xedn': 405122.0,
#  u'T\xe2rgu Mure\u015f': 134290.0,
#  'Juba': 372410.0,
#  'Envigado': 217343.0,
#  'Corona': 152374.0,
#  'Sumgayit': 290500.0,
#  'Marsa Matruh': 206400.0,
#  u'Tulu\xe1': 209086.0,
#  'Samut Prakan': 277600.0,
#  'Denpasar': 788589.0,
#  u'Ciudad Bol\xedvar': 307713.0,
#  'Yanan': 113277.0,
#  'Varna': 330486.0,
#  'Gumushane': 100712.0,
#  'Piacenza': 100311.0,
#  'Valdivia': 127750.0,
#  'Fresno': 509924.0,
#  u'Z\xfcrich': 384786.0,
#  'Boma': 135284.0,
#  'Hialeah': 224667.0,
#  'Oskemen': 314014.0,
#  'Tawau': 213745.0,
#  'Uribia': 168286.0,
#  'Rouen': 111553.0,
#  'Maribor': 111374.0,
#  "Al Isma'iliyah": 300449.0,
#  'Naperville': 142089.0,
#  'Warren': 134056.0,
#  'Talcahuano': 161692.0,
#  'Nyala': 227183.0,
#  'Guixian': 114025.0,
#  'Baia Mare': 123738.0,
#  'Santa Cruz de Tenerife': 204476.0,
#  'Puyang': 175988.0,
#  'Kaohsiung': 2778659.0,
#  u'Cob\xe1n': 232703.0,
#  u'S\xe3o Bernardo do Campo': 752658.0,
#  'Soroe': 549050.0,
#  'Algeciras': 117695.0,
#  'Najran': 521273.0,
#  'Edinburgh': 459366.0,
#  'Kikwit': 182142.0,
#  'Kyzyl': 109918.0,
#  u'Viam\xe3o': 224943.0,
#  'Ajaccio': 66245.0,
#  'Peoria': 115021.0,
#  'Praha': 1289556.0,
#  'Trnava': 66358.0,
#  'Ho': 104532.0,
#  'Armenia': 295143.0,
#  'Resistencia': 274001.0,
#  'Port-of-Spain': 548299.0,
#  'Kristianstad': 80507.0,
#  'Kota': 1001694.0,
#  'Baoji': 337765.0,
#  'Bitlis': 98424.0,
#  'Graz': 269211.0,
#  'Alajuela': 257382.0,
#  'Tegal': 239599.0,
#  'Freetown': 772873.0,
#  'Bhatpara': 315976.0,
#  'Bokara Steel City': 333683.0,
#  'Cape Town': 3740026.0,
#  'Apopa': 143718.0,
#  'Changzhou': 3290918.0,
#  'Longyan': 134481.0,
#  'Narayanganj': 286330.0,
#  'Warszawa': 1711324.0,
#  'Cabimas': 207996.0,
#  'Montreuil': 103068.0,
#  'Madison': 233362.0,
#  'Gomel': 482652.0,
#  'Pingxiang': 425579.0,
#  'Lahti': 103396.0,
#  'Cajamarca': 162326.0,
#  'Koforidua': 120971.0,
#  'Douala': 1907479.0,
#  "Saint George's": 37000.0,
#  'Chaozhou': 313469.0,
#  'Essen': 566201.0,
#  'Chemnitz': 240253.0,
#  u'San Nicol\xe1s de los Garzas': 443273.0,
#  'Lugano': 62792.0,
#  'Puerto Inirida': 500097.0,
#  'Xuancheng': 112673.0,
#  'Dallas': 1257676.0,
#  'Moshi': 184292.0,
#  'Thai Nguyen': 199732.0,
#  u'Ciego de \xc1vila': 124103.0,
#  'Adana': 1636229.0,
#  'Nacala Porto': 206449.0,
#  'Latina': 117892.0,
#  'Ewo': 128032.0,
#  'Concordia': 137046.0,
#  'Shubra al Khimah': 1016722.0,
#  'Limoges': 137758.0,
#  'Baguio': 301926.0,
#  'Huichon': 168180.0,
#  'Firenze': 358079.0,
#  'Gambella': 262884.0,
#  'Bandjarmasin': 625481.0,
#  u'Asunci\xf3n': 518792.0,
#  'Hobart': 216276.0,
#  u'S\xe3o Jos\xe9 dos Campos': 617106.0,
#  'Allahabad': 1112544.0,
#  'Mbanza Congo': 183691.0,
#  'Kolwezi': 417810.0,
#  'Sanya': 102820.0,
#  u'San Miguel de Tucum\xe1n': 525853.0,
#  'Frauenfeld': 74581.0,
#  'Nagano': 445432.0,
#  'Pereira': 467185.0,
#  'Dashhowuz': 165400.0,
#  'Kaspijsk': 100129.0,
#  'Pimpri Chinchwad': 1727692.0,
#  'Nema': 49152.0,
#  'Reykjavik': 118061.0,
#  'Yaren': 6444.0,
#  'La Palma': 144858.0,
#  'Piracicaba': 356743.0,
#  'Rio Grande': 189429.0,
#  'Stara Zagora': 136363.0,
#  'Shihezi': 299676.0,
#  'Wuzhou': 210452.0,
#  'Skikda': 182903.0,
#  u'Sevastopol\xb4': 340559.0,
#  'Kagoshima': 605120.0,
#  'Najafabad': 221814.0,
#  'Townsville': 167636.0,
#  u'Chimalhuac\xe1n': 612383.0,
#  u'T\xe1ranto': 200154.0,
#  'Liupanshui': 363954.0,
#  'Granada': 123697.0,
#  'Vila Nova de Gaia': 72576.0,
#  'Rizhao': 185048.0,
#  'Maputo': 1094628.0,
#  'Raipur': 1010433.0,
#  'Lhasa': 106885.0,
#  'Fargo': 105549.0,
#  'Neijiang': 256012.0,
#  'Gaza': 449477.0,
#  'Porto Alegre': 1409351.0,
#  'Osijek': 83496.0,
#  'Likasi': 299118.0,
#  'Funabashi': 602996.0,
#  'Kawaguchi': 557710.0,
#  'Mwanza': 706453.0,
#  'Bhisho': 77682.0,
#  'Gorno Altaysk': 56933.0,
#  'Chilpancingo': 187251.0,
#  'Haining': 100478.0,
#  'Guntur': 471051.0,
#  'Brugge': 117577.0,
#  'Miass': 151751.0,
#  'Saipan': 123516.0,
#  'San Pedro Sula': 515458.0,
#  'Kolomna': 144589.0,
#  'Worthing': 109120.0,
#  'San Justo': 1256724.0,
#  'Barisal': 328278.0,
#  'Wichita': 382386.0,
#  'Chitungwiza': 356840.0,
#  'Melbourne': 4169103.0,
#  'Haiphong': 846191.0,
#  'Saltillo': 709671.0,
#  'Kuantan': 283041.0,
#  'Quito': 1619146.0,
#  'Sosnowiec': 214488.0,
#  'Dalian': 4087733.0,
#  'Apia': 36735.0,
#  'Qujing': 178669.0,
#  'Papeete': 75225.0,
#  'Tambacounda': 177662.0,
#  'Zhoukou': 146288.0,
#  'Safi': 284750.0,
#  'Samara': 1171598.0,
#  'Sankt Peterburg': 5028000.0,
#  'Jamshedpur': 478950.0,
#  'Sunderland': 174286.0,
#  'Liuzhou': 609320.0,
#  'Nouakchott': 958399.0,
#  'Dumai': 253803.0,
#  'Aligarh': 480520.0,
#  'Ciudad de Guatemala': 992541.0,
#  'Zunyi': 261862.0,
#  'Iseyin': 170936.0,
#  'Wulumuqi': 3029372.0,
#  'Szeged': 168048.0,
#  "P'atigorsk": 142511.0,
#  'Torino': 872367.0,
#  'Dundee': 147285.0,
#  'Khorramshahr': 129418.0,
#  'Ipswich': 144957.0,
#  'Tsu': 409157.0,
#  'Lleida': 137283.0,
#  'Meerut': 1305429.0,
#  'Al Basrah': 1400000.0,
#  'Khoy': 200958.0,
#  'Kherson': 300666.0,
#  'Columbia': 130038.0,
#  'Ipoh': 566211.0,
#  'Verona': 252520.0,
#  'Korla': 159344.0,
#  'Santa Maria': 248347.0,
#  'Witten': 96382.0,
#  'Bolu': 131264.0,
#  'Touba': 356840.0,
#  'Kislovodsk': 128553.0,
#  'Atlanta': 420279.0,
#  'Orel': 318136.0,
#  u'Forl\xed': 116434.0,
#  'Manokwari': 136302.0,
#  'Kigali': 603049.0,
#  'Iraklio': 173993.0,
#  u'Zl\xedn': 77137.0,
#  u'\u010cerkessk': 129069.0,
#  'Dourados': 181005.0,
#  'Victoria de las Tunas': 167424.0,
#  'Stockton': 291731.0,
#  'Niamey': 1026848.0,
#  'Shymkent': 683273.0,
#  'Shashi': 281352.0,
#  'Luan': 144248.0,
#  'Harbin': 5878939.0,
#  'Nevsehir': 92068.0,
#  'Kanpur': 2765348.0,
#  u'Divin\xf3polis': 207516.0,
#  'Zabrze': 179861.0,
#  'Al Uqsur': 451318.0,
#  'Kuala Terengganu': 250528.0,
#  'Ujjain': 362633.0,
#  'Juazeiro': 160775.0,
#  'Syracuse': 145196.0,
#  'Santa Barbara': 84641.0,
#  'Al Hasakah': 254622.0,
#  'Camaragibe': 144466.0,
#  'Southend-on-Sea': 175547.0,
#  'Kim Chaek': 207299.0,
#  u'K\xe9nitra': 359142.0,
#  'Monza': 119856.0,
#  'Dakar': 1121935.0,
#  u'Cuman\xe1': 208114.0,
#  'Sorocaba': 580655.0,
#  "L'ubercy": 172525.0,
#  'Burlington': 175779.0,
#  'Takoradi': 311206.0,
#  'Aosta': 872367.0,
#  u'Ume\xe5': 117294.0,
#  'Thimphu': 42465.0,
#  'Antipolo': 633971.0,
#  'Saint Catharines': 131400.0,
#  'Horlivka': 258879.0,
#  'Sheffield': 518090.0,
#  'Guangzhou': 11071424.0,
#  'Hefei': 3310268.0,
#  'Kuala Lumpur': 1297526.0,
#  'Eskisehir': 659924.0,
#  'Lelystad': 76252.0,
#  'Luoyang': 1190000.0,
#  'Honolulu': 337256.0,
#  'Yizheng': 109268.0,
#  'Bern': 128848.0,
#  'Grenoble': 157424.0,
#  'Yamoussoukro': 207412.0,
#  'Odesa': 1008162.0,
#  "Nazran'": 93335.0,
#  u'Boca del R\xedo': 126507.0,
#  'Boise City': 206105.0,
#  'Paderborn': 142365.0,
#  'Reutlingen': 109799.0,
#  u'Mekn\xe8s': 469169.0,
#  'Nova Friburgo': 159372.0,
#  'Uzhhorod': 116556.0,
#  u'Kecskem\xe9t': 111411.0,
#  u'Ko\u0161ice': 240433.0,
#  'Nonthaburi': 481900.0,
#  'Sunnyvale': 140058.0,
#  'Mangaung': 747431.0,
#  'David': 144858.0,
#  'Bida': 111245.0,
#  'Huzhou': 218071.0,
#  'Khorugh': 96800.0,
#  'Mainz': 200344.0,
#  'Heilbronn': 116059.0,
#  'Uberaba': 289376.0,
#  'Rostov-na-Donu': 1103733.0,
#  'Andorra la Vella': 22256.0,
#  'Jinhua': 144280.0,
#  'Tlalnepantla': 653410.0,
#  'Ngiva': 513000.0,
#  'Tilburg': 210283.0,
#  'Antofagasta': 285255.0,
#  'Chaoyang': 222394.0,
#  'Shuangyashan': 386081.0,
#  'Mudanjiang': 571705.0,
#  'Porto-Novo': 223552.0,
#  'Kustanay': 221970.0,
#  'Lansing': 114297.0,
#  'Juazeiro do Norte': 240128.0,
#  'Shuangcheng': 142659.0,
#  'Arapiraca': 181481.0,
#  'Yoro': 64425.0,
#  'South Bend': 101075.0,
#  'Opole': 122120.0,
#  'Canoas': 323827.0,
#  u'Neuqu\xe9n': 201729.0,
#  'Tunceli': 243735.0,
#  u'Wa\u0142brzych': 119216.0,
#  'Nossa Senhora do Socorro': 155823.0,
#  'Aioun': 49152.0,
#  'Luena': 513000.0,
#  'Kazan': 1176187.0,
#  u'Vit\xf3ria': 327801.0,
#  'Pokhara': 264991.0,
#  'Orlando': 238834.0,
#  'Zigong': 393184.0,
#  'Termiz': 136200.0,
#  'Mata-Utu': 44040.0,
#  'Castanhal': 153378.0,
#  'Pforzheim': 114411.0,
#  'Ogbomosho': 433030.0,
#  'Antwerpen': 507911.0,
#  'Chachapoyas': 104011.0,
#  'Bata': 66800.0,
#  'Ayacucho': 151019.0,
#  'Saga': 974691.0,
#  'Benxi': 768778.0,
#  u'Lim\xf3n': 107219.0,
#  'Sanmenxia': 120523.0,
#  'Costa Mesa': 109935.0,
#  ...}

# %%
sorted_city_population = sorted(city_population.items(), key=lambda x: x[1], reverse=True)
sorted_city_population[0:10]
# Out:
# [('Shanghai', 22315474.0),
#  ('Istanbul', 13710512.0),
#  ('Mumbai', 12442373.0),
#  ('Moskva', 11979529.0),
#  ('Beijing', 11716620.0),
#  (u'S\xe3o Paulo', 11152344.0),
#  ('Tianjin', 11090314.0),
#  ('Guangzhou', 11071424.0),
#  ('Delhi', 11034555.0),
#  ('Shenzhen', 10358381.0)]

# %% [markdown]
# ### 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %% [markdown]
# I will assume that the population of any country = the latest census of this country

# %%
ethinc_population = {}
for country in document.findall('country'):
    latest_population_year = 0
    for country_population in country.findall('population'):
        population_year = int(country_population.get('year'))
        if(population_year > latest_population_year):
            latest_population_year = population_year
            latest_country_population = float(population.text)
    for country_ethinc_group in country.findall('ethnicgroup'):
        ethinc_group_name = country_ethinc_group.text
        ethinc_group_precentage = float(country_ethinc_group.get('percentage'))
        if ethinc_group_name in ethinc_population.keys():
            ethinc_population[ethinc_group_name] = ethinc_population[ethinc_group_name] +\
                ethinc_group_precentage * latest_country_population
        else :
            ethinc_population[ethinc_group_name] = ethinc_group_precentage * latest_country_population
ethinc_population
# Out:
# {'Acholi': 99880.0,
#  'Afar': 916399.0,
#  'African': 46657693.5,
#  'African descent': 1248500.0,
#  'African-white-Indian': 2247300.0,
#  'Afro-Asian': 249700.0,
#  'Afro-Chinese': 29964.0,
#  'Afro-East Indian': 74910.0,
#  'Afro-European': 377047.0,
#  'Albanian': 5423484.0,
#  'Alemannic': 2372150.0,
#  'Americo-Liberians': 124850.0,
#  'Amerindian': 4553778.9,
#  'Amhara': 671693.0,
#  'Andorran': 824010.0,
#  'Arab': 15938351.0,
#  'Arab Iranian': 574310.0,
#  'Arab-Berber': 7393617.0,
#  'Arabic': 34458.6,
#  'Armenian': 2609365.0,
#  'Asian': 2307977.1,
#  'Assyrian': 124850.0,
#  'Austrian': 2274767.0,
#  'Aymara': 624250.0,
#  'Azerbaijani': 599280.0,
#  'Azeri': 2424587.0,
#  'Baganda': 424490.0,
#  'Bagisu': 124850.0,
#  'Bahraini': 1573110.0,
#  'Bakongo': 324610.0,
#  'Baloch': 49940.0,
#  'Banda': 674190.0,
#  'Bantu': 2372150.0,
#  'Baoule': 574310.0,
#  'Bashkir': 29964.0,
#  'Basogo': 199760.0,
#  'Basques Bretons': 2497000.0,
#  'Batobo': 74910.0,
#  'Batswana': 2372150.0,
#  'Baya': 848980.0,
#  'Beja': 149820.0,
#  'Belorussian': 2189869.0,
#  'Bengali': 2447060.0,
#  'Berber Arab': 2422090.0,
#  'Beri Beri': 107371.0,
#  'Bete': 449460.0,
#  'Bhote': 1248500.0,
#  'Bilen': 49940.0,
#  'Black': 6379835.0,
#  'Black Maur': 998800.0,
#  'Borneo indigenous': 274670.0,
#  'Bosniak': 1196063.0,
#  'Bounty': 2497000.0,
#  'British Isles': 699160.0,
#  'Bulgarian': 1977624.0000000002,
#  'Bunyoro': 74910.0,
#  'Burman': 1697960.0,
#  'Byelorussian': 12485.0,
#  'Cameroon Highlanders': 774070.0,
#  'Carib Indians': 2497000.0,
#  'Caribbean': 19976.0,
#  'Caucasian': 94886.0,
#  'Celt': 2497000.0,
#  'Chamorro': 926387.0,
#  'Chinese': 11808313.0,
#  'Christian': 1677984.0,
#  'Chuvash': 27467.000000000004,
#  'Circassian': 24970.0,
#  'Colored': 214742.0,
#  'Creole': 3842883.0,
#  'Crimean Tatar': 12485.0,
#  'Croat': 2746700.0,
#  'Czech': 2282258.0,
#  'Dagestani': 54934.00000000001,
#  'Danish': 349580.0,
#  'Diola': 224730.0,
#  'Djerma': 549340.0,
#  'Dravidian': 624250.0,
#  'Dungan': 27467.000000000004,
#  'Dutch': 2015079.0,
#  'East Indian': 2164899.0,
#  'Eastern Hamitic': 2472030.0,
#  'Eastern Nigritic': 174790.0,
#  'Emiri': 474430.0,
#  'English': 2087491.9999999998,
#  'Equatorial Bantu': 474430.0,
#  'Estonian': 1722930.0,
#  'Euro-African': 4994.0,
#  'Euronesians': 174790.0,
#  'European': 24241375.4,
#  'European Lebanese': 24970.0,
#  'European Syrian-Lebanese': 24970.0,
#  'European/Caribbean Amerindian': 1997600.0,
#  'Europeans': 34958.0,
#  'Fijian': 1223530.0,
#  'Filipino': 696663.0,
#  'Finn': 2477024.0,
#  'Fleming': 1448260.0,
#  'Franco-Mauritian': 49940.0,
#  'French': 2709245.0,
#  'Fula': 212245.0,
#  'Fulani': 674190.0,
#  'Gagauz': 109868.00000000001,
#  'Garifuna': 152317.0,
#  'Georgian': 2092486.0,
#  'German': 4135032.0,
#  'Gilaki Mazandarani': 199760.0,
#  'Gourmantche': 29964.0,
#  'Greek': 4319810.0,
#  'Greenlander': 2147420.0,
#  'Gurage': 62425.0,
#  'Gypsy': 67419.0,
#  'Hadiya': 42449.0,
#  'Han Chinese': 2284755.0,
#  'Hausa': 1398320.0,
#  'Hazara': 474430.0,
#  'Hindustani': 923890.0,
#  'Hungarian': 2834095.0,
#  'Hutu': 1997600.0,
#  'Indian': 2096980.6,
#  'Indo-Aryan': 1797840.0,
#  'Indo-Mauritian': 1697960.0,
#  'Indonesian': 154814.0,
#  'Inuit': 49940.0,
#  'Iranian': 549340.0,
#  'Irish': 2182378.0,
#  'Italian': 1081201.0,
#  'Iteso': 199760.0,
#  'Japanese': 2482018.0,
#  'Javanese': 1505691.0,
#  'Jewish': 2382138.0,
#  'Kalenjin': 299640.0,
#  'Kamba': 274670.0,
#  'Karakalpak': 62425.0,
#  'Karamojong': 299640.0,
#  'Karen': 174790.0,
#  'Kazak': 199760.0,
#  'Kazakh': 1575607.0,
#  'Kgalagadi': 99880.0,
#  'Khmer': 2284755.0,
#  'Kikuyu': 549340.0,
#  'Kimbundu': 624250.0,
#  'Kirdi': 274670.0,
#  'Kisii': 149820.0,
#  'Kunama': 49940.0,
#  'Kurd': 174790.0,
#  'Kurdish': 673440.9,
#  'Kuwaiti': 1123650.0,
#  'Kyrgyz': 1648020.0000000002,
#  'Langi': 149820.0,
#  'Lao Loum': 1697960.0,
#  'Lao Soung Hmong Yao': 224730.0,
#  'Lao Theung': 549340.0,
#  'Latvian': 1480721.0,
#  'Lithuanian': 2129941.0,
#  'Lugbara': 99880.0,
#  'Luhya': 349580.0,
#  'Luo': 324610.0,
#  'Lur': 49940.0,
#  'Luxembourgish': 1575607.0,
#  'MBaka': 99880.0,
#  'Macedonian': 1665499.0,
#  'Madurese': 187275.0,
#  'Malay': 6050231.0,
#  'Malinke': 1023770.0,
#  'Mande': 1248500.0,
#  'Mandingo': 224730.0,
#  'Mandjia': 524370.0,
#  'Mangbetu-Azande': 1123650.0,
#  'Maori': 184778.0,
#  'Maur': 749100.0,
#  'Maya': 264682.0,
#  'Mboum': 99880.0,
#  'Mediterranean Nordic': 2497000.0,
#  'Melanesian': 5770567.0,
#  'Meru': 149820.0,
#  'Mestizo': 21741379.0,
#  'Micronesian': 5031455.0,
#  'Mixed': 1293446.0,
#  'Moldavian/Romanian': 1952654.0,
#  'Moldovan': 12485.0,
#  'Mon': 49940.0,
#  'Monegasque': 539352.0,
#  'Mong': 29964.0,
#  'Mongol': 2444563.0,
#  'Montenegrin': 1096183.0,
#  'Moravian': 92389.0,
#  'Moroccan': 49940.0,
#  'Mossi': 599280.0,
#  'Mulatto': 3623147.0,
#  'Muong': 37455.0,
#  'Muslim': 1221033.0,
#  'Nauruan': 1448260.0,
#  'Nepalese': 873950.0,
#  'None': 786555.0,
#  'Norman-French': 4994000.0,
#  'Northern Irish': 72413.0,
#  'Northwestern Bantu': 199760.0,
#  'Norwegian': 3443363.0,
#  'Nung': 27467.000000000004,
#  'Oromo': 861465.0,
#  'Ovimbundu': 923890.0,
#  'Pacific Islander': 1670493.0,
#  'Pakistani': 481921.0,
#  'Palestinian Arab': 4554528.0,
#  'Pashtun': 948860.0,
#  'Persian': 1273470.0,
#  'Peuhl': 1423290.0,
#  'Polish': 2771670.0,
#  'Polynesian': 16642505.0,
#  'Portuguese': 681681.0,
#  'Quechua': 749100.0,
#  'Rakhine': 99880.0,
#  'Rashaida': 49940.0,
#  'Roma': 304634.0,
#  'Romanian': 2249797.0,
#  'Romansch': 24970.0,
#  'Russian': 5595777.0,
#  'Russian Ukrainian': 1106171.0,
#  'Ruthenian': 7491.0,
#  'Rwanda': 149820.0,
#  'Saho': 99880.0,
#  'Sami': 37455.0,
#  'Samoan': 4534552.0,
#  'Sara': 249700.0,
#  'Scandinavian': 2497000.0,
#  'Scottish': 214742.0,
#  'Senoufou': 374550.0,
#  'Serb': 3126244.0,
#  'Serbian': 124850.0,
#  'Serbs': 49940.0,
#  'Serer': 424490.0,
#  'Seychellois': 2497000.0,
#  'Shan': 224730.0,
#  'Sidama': 99880.0,
#  'Sinhalese': 1847780.0,
#  'Sino-Mauritian': 74910.0,
#  'Slovak': 2207348.0,
#  'Slovene': 2309725.0,
#  'Somali': 3775464.0,
#  'Songhai': 149820.0,
#  'Sotho': 2489509.0,
#  'Soussou': 499400.0,
#  'South Asian': 1473230.0,
#  'Spanish': 1073710.0,
#  'Sundanese': 349580.0,
#  'Surinamese': 49940.0,
#  'Swede': 2212342.0,
#  'Taiwanese': 2097480.0,
#  'Tajik': 2744203.0,
#  'Tamil': 449460.0,
#  'Tatar': 164802.0,
#  'Tay': 47443.0,
#  'Thai': 1917696.0,
#  'Tigraway': 152317.0,
#  'Tigre': 749100.0,
#  'Tigrinya': 1373350.0,
#  'Tongan': 99880.0,
#  'Toucouleur': 224730.0,
#  'Tuareg': 449460.0,
#  'Turkish': 3017374.8000000003,
#  'Turkmen': 2172390.0,
#  'Tutsi': 474430.0,
#  'Twa': 24970.0,
#  'Uighur': 59928.0,
#  'Ukrainian': 2484515.0,
#  'Uzbek': 3068813.0,
#  'Vedda': 24970.0,
#  'Viet/Kinh': 2139929.0,
#  'Vietnamese': 159808.0,
#  'Vietnamese/Chinese': 24970.0,
#  'Voltaic': 299640.0,
#  'Wallisian': 224730.0,
#  'Walloon': 774070.0,
#  'Welaita': 57430.99999999999,
#  'Welsh': 122353.00000000001,
#  'White': 4244900.0,
#  'Wolof': 898920.0,
#  'Yezidi': 32461.0,
#  'black-Amerindian': 74910.0}

# %%
sorted_ethinc_population = sorted(ethinc_population.items(), key=lambda x: x[1], reverse=True)
sorted_ethinc_population[0:10]
# Out:
# [('African', 46657693.5),
#  ('European', 24241375.4),
#  ('Mestizo', 21741379.0),
#  ('Polynesian', 16642505.0),
#  ('Arab', 15938351.0),
#  ('Chinese', 11808313.0),
#  ('Arab-Berber', 7393617.0),
#  ('Black', 6379835.0),
#  ('Malay', 6050231.0),
#  ('Melanesian', 5770567.0)]

# %% [markdown]
# ### 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
longest_river_length = 0
for river in document.findall('river'):
    if(river.find('length') is not None):
        river_length = float(river.find('length').text)
    if(river_length > longest_river_length):
        longest_river_length = river_length
        longest_river_name = river.find('name').text
        if(river.find('source') is not None):
            longest_river_country_code = river.find('source').get('country')
        else:
            longest_river_country_code = river.get('country')
longest_river_country = document.find(".//country[@car_code='"+longest_river_country_code+"']")
longest_river_country_name = longest_river_country.find('name').text
print longest_river_name,longest_river_length,longest_river_country_name
# Out:
# Amazonas 6448.0 Peru

# %%
largest_lake_area = 0
for lake in document.findall('lake'):
    if(lake.find('area') is not None):
        lake_area = float(lake.find('area').text)
    if(lake_area > largest_lake_area):
        largest_lake_area = lake_area
        largest_lake_name = lake.find('name').text
        if(lake.find('located') is not None):
            largest_lake_country_code = lake.find('located').get('country')
        else:
            largest_lake_country_code = lake.get('country')
largest_lake_country = document.find(".//country[@car_code='"+largest_lake_country_code+"']")
largest_lake_country_name = largest_lake_country.find('name').text
print largest_lake_name,largest_lake_area,largest_lake_country_name
# Out:
# Caspian Sea 386400.0 Russia

# %%
highest_air_port_elevation = 0
for airport in document.findall('airport'):
    if(airport.find('elevation').text is not None):
        air_port_elevation = float(airport.find('elevation').text)
    if(air_port_elevation > highest_air_port_elevation):
        highest_air_port_elevation = air_port_elevation
        highest_air_port_name = airport.find('name').text
        highest_air_port_country_code = airport.get('country')
highest_air_port_country = document.find(".//country[@car_code='"+highest_air_port_country_code+"']")
highest_air_port_country_name = highest_air_port_country.find('name').text
print highest_air_port_name,highest_air_port_elevation,highest_air_port_country_name
# Out:
# El Alto Intl 4063.0 Bolivia
